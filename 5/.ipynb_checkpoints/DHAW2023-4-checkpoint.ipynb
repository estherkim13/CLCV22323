# %% [markdown]
# ## Read and Write to files

# %% [markdown]
# When we use the `open()` function in Python, we pass two argument: __1)__ the file and __2)__ the mode, e.g., `open("mydiary.text, "r")`. Some times, you may need to declare also __3)__ the encoding.
#
# __1.__ The file should always contain the extension of the file (e.g., ".txt" or ".html"). If the file we want to open is not in the same directory as the Jupyter Notebook, we must write the directory of the file. E.g.:
#
# For Mac users:
#
# - `open("/Users/Georgios/Desktop/Downloads/GitHub/4/mydiary.text", "r")`
#
# For Windows users:
#
# - `open("C:/Users/Georgios/Downloads/GitHub/4/mydiary.text", "r")`
#
#     or:
#
# - `open(r"C:\Users\Georgios\Downloads\GitHub\4\mydiary.text", "r")`
#
# __2.__ There are several modes. The most useful:
# - `"r"`: This is the default mode. It opens a file only for reading.
# - `"a"`: It opens a file for appending.
# - `"w"`: It opens a file for writing.
#
# __3__ To specify the encoding, you can pass the following parameters:
# - encoding="utf-8"
# - encoding="ascii"

# %% [markdown]
# ### Read

# %% [markdown]
# #### Reading a file (slow way)

# %%
f = open("myfile.txt","r")
text = f.readlines()
f.close()

# %%
print(text)
# Out:
# ['Γεώργιος Τσολάκης']

# %% [markdown]
# #### Reading a file (fast way)

# %%
with open("myfile.txt", "r", encoding="utf-8") as f:
    text = f.readlines()

# %%
print(text)
# Out:
# ['When Mr Bilbo Baggins of Bag End announced that he would shortly be celebrating his eleventyifirst birthday with a party of special magnificence, there was much talk and excitement in Hobbiton.\n']

# %% [markdown]
# #### Reading a file with encoding

# %%
with open("myGreekfile.txt", "r") as f:
    text = f.readlines()

# %% [markdown]
# You have probably received an error messge. Try the opening the file with encoding.

# %%
with open("myGreekfile.txt", "r", encoding="utf-8") as f:
    text = f.readlines()

# %%
print(text)
# Out:
# ['Γεώργιος Τσολάκης']

# %% [markdown]
# #### Writing a file (slow way)

# %% [markdown]
# ### Write

# %% [markdown]
# #### Append
# The following code will either create a new file and will write a text or will _append_ the text to an existing file. Run the cell once and open the file in your computer (not with Python). Then close the file and run the following cell three times. Open the file again. What do you notice?

# %%
f = open("newfile.txt", "a")
f.write("I love Digital Humanities!")
f.close()

# %% [markdown]
# #### Writing a file
# The following code will either create a new file and will write a text or will _overwrite_ the text to an existing file.

# %%
f = open("newfile.txt", "w")
f.write("I love Digital Humanities!")
f.close()

# %% [markdown]
# Regardless of how many times you run the code, the result will remain the same.

# %% [markdown]
# #### Writing a file (fast way)

# %%
with open("newfile.txt", "w") as f:
    f.write("I love Digital Humanities!")

# %% [markdown]
# Make the necessary changes to the following code to run without errors.

# %%
with open("newfile.txt", "w") as f:
    f.write("I love Digital Humanities! Γεώργιος is teaching the course!")

# %% [markdown]
# ## Pandas and CSV/EXCEL

# %% [markdown]
# For some types of files, we need specific libraries. Those libraries are included by default with the Python distribution, while other need to be installed manually.
#
# For files in a tabular format, like .csv (comma seperated values) or .xslx (Excel), Pandas are a powerful tool. In order to install Pandas:
#
# For Mac users:
# - Click the Launchpad icon in the Dock, type "Terminal" in the search field, then click Terminal or (Click the magnifying glass icon in the menu bar or press Command + Space. Type "Terminal" and double-click the Terminal app).
# - Type `pip3 install pandas` and press Return.
#
# For Windows users:
# - Press the Windows button and type "cmd".
# - Open the `Command Prompt`
# - Type `pip install pandas` and press enter.

# %% [markdown]
# #### Libraries - Imports

# %% [markdown]
# Installing a library is not enough. We must import it.

# %%
import pandas as pd # This is a convention in Python community.

# %% [markdown]
# #### Read

# %% [markdown]
# Download the csv of [Roman Amphitheaters](https://github.com/roman-amphitheaters/roman-amphitheaters/blob/main/roman-amphitheaters.csv) and place it in the same directory as your notebook. Run the following cells.

# %%
df = pd.read_csv('roman-amphitheaters.csv') #

# %% [markdown]
# `df` stands for dataframe, i.e., rows and columns of data.

# %%
df
# Out:
#                                  id  \
# 0           duraEuroposAmphitheater
# 1                 arlesAmphitheater
# 2                  lyonAmphitheater
# 3                  ludusMagnusArena
# 4           romeFlavianAmphitheater
# ..                              ...
# 270  saintGeorgesDuBoisAmphitheater
# 271              toledoAmphitheater
# 272        kaiseraugustAmphitheater
# 273              ammaiaAmphitheater
# 274          contributaAmphitheater
#
#                                           title                  label  \
# 0                  Amphitheater at Dura Europos           Dura Europos
# 1                         Amphitheater at Arles                  Arles
# 2                          Amphitheater at Lyon                   Lyon
# 3                            Ludus Magnus Arena           Ludus Magnus
# 4                  Flavian Amphitheater at Rome   Flavian Amphitheater
# ..                                          ...                    ...
# 270       Amphitheater at Saint-Georges-du-Bois  Saint-Georges-du-Bois
# 271                      Amphitheater at Toledo                 Toledo
# 272                 Amphitheater at Kaiseraugst            Kaiseraugst
# 273                      Amphitheater at Ammaia                 Ammaia
# 274  Amphitheater at Contributa Iulia Ugultunia             Contributa
#
#                    latintoponym                                   pleiades  \
# 0                  Dura Europus    https://pleiades.stoa.org/places/893989
# 1                       Arelate    https://pleiades.stoa.org/places/148217
# 2                      Lugdunum    https://pleiades.stoa.org/places/167717
# 3                  Ludus Magnus    https://pleiades.stoa.org/places/423025
# 4                          Roma    https://pleiades.stoa.org/places/423025
# ..                          ...                                        ...
# 270                         NaN                                        NaN
# 271                     Toletum    https://pleiades.stoa.org/places/266066
# 272          Castrum Rauracense  https://pleiades.stoa.org/places/81716458
# 273                      Ammaia    https://pleiades.stoa.org/places/255975
# 274  Contributa Iulia Ugultunia    https://pleiades.stoa.org/places/256126
#
#      welchid  golvinid    buildingtype     chronogroup  secondcentury  ...  \
# 0        NaN     129.0    amphitheater         severan          False  ...
# 1        NaN     154.0    amphitheater         flavian           True  ...
# 2        NaN     171.0    amphitheater  second-century           True  ...
# 3        NaN       NaN  practice-arena        imperial          False  ...
# 4        NaN     152.0    amphitheater         flavian           True  ...
# ..       ...       ...             ...             ...            ...  ...
# 270      NaN     103.0    amphitheater   first-century           True  ...
# 271      NaN       NaN    amphitheater        imperial           True  ...
# 272      NaN       NaN    amphitheater  fourth-century          False  ...
# 273      NaN       NaN    amphitheater        imperial           True  ...
# 274      NaN       NaN    amphitheater        imperial           True  ...
#
#                            amphitheatrum dimensionsunknown arenamajor  \
# 0    https://amphi-theatrum.de/1449.html             False       31.0
# 1    https://amphi-theatrum.de/1371.html             False       47.0
# 2    https://amphi-theatrum.de/1416.html             False       67.6
# 3    https://amphi-theatrum.de/1708.html              True        NaN
# 4    https://amphi-theatrum.de/1373.html             False       83.0
# ..                                   ...               ...        ...
# 270  https://amphi-theatrum.de/1529.html             False       54.0
# 271  https://amphi-theatrum.de/3090.html              True        NaN
# 272  https://amphi-theatrum.de/3066.html             False        NaN
# 273  https://amphi-theatrum.de/3020.html             False        NaN
# 274  https://amphi-theatrum.de/3093.html             False        NaN
#
#     arenaminor extmajor  extminor  exteriorheight  longitude   latitude  \
# 0         25.0     50.0      44.0             NaN  40.728926  34.749855
# 1         32.0    136.0     107.0             NaN   4.631111  43.677778
# 2         42.0    143.0     117.0             NaN   4.830556  45.770556
# 3          NaN      NaN       NaN             NaN  12.494913  41.889950
# 4         48.0    189.0     156.0            52.0  12.492269  41.890169
# ..         ...      ...       ...             ...        ...        ...
# 270       30.0     65.0      50.0             NaN  -0.749919  46.142723
# 271        NaN      NaN       NaN             NaN  -4.022888  39.865349
# 272        NaN     50.0      40.0             NaN   7.721596  47.540822
# 273        NaN     60.0       NaN             NaN  -7.391970  39.369905
# 274        NaN     72.0       NaN             NaN  -6.389320  38.347751
#
#      elevation
# 0          223
# 1           21
# 2          206
# 3           22
# 4           22
# ..         ...
# 270         39
# 271        482
# 272        482
# 273        566
# 274        501
#
# [275 rows x 24 columns]

# %%
df.head()
# Out:
#                         id                         title  \
# 0  duraEuroposAmphitheater  Amphitheater at Dura Europos
# 1        arlesAmphitheater         Amphitheater at Arles
# 2         lyonAmphitheater          Amphitheater at Lyon
# 3         ludusMagnusArena            Ludus Magnus Arena
# 4  romeFlavianAmphitheater  Flavian Amphitheater at Rome
#
#                   label  latintoponym  \
# 0          Dura Europos  Dura Europus
# 1                 Arles       Arelate
# 2                  Lyon      Lugdunum
# 3          Ludus Magnus  Ludus Magnus
# 4  Flavian Amphitheater          Roma
#
#                                   pleiades  welchid  golvinid    buildingtype  \
# 0  https://pleiades.stoa.org/places/893989      NaN     129.0    amphitheater
# 1  https://pleiades.stoa.org/places/148217      NaN     154.0    amphitheater
# 2  https://pleiades.stoa.org/places/167717      NaN     171.0    amphitheater
# 3  https://pleiades.stoa.org/places/423025      NaN       NaN  practice-arena
# 4  https://pleiades.stoa.org/places/423025      NaN     152.0    amphitheater
#
#       chronogroup  secondcentury  ...                        amphitheatrum  \
# 0         severan          False  ...  https://amphi-theatrum.de/1449.html
# 1         flavian           True  ...  https://amphi-theatrum.de/1371.html
# 2  second-century           True  ...  https://amphi-theatrum.de/1416.html
# 3        imperial          False  ...  https://amphi-theatrum.de/1708.html
# 4         flavian           True  ...  https://amphi-theatrum.de/1373.html
#
#   dimensionsunknown arenamajor arenaminor extmajor  extminor  exteriorheight  \
# 0             False       31.0       25.0     50.0      44.0             NaN
# 1             False       47.0       32.0    136.0     107.0             NaN
# 2             False       67.6       42.0    143.0     117.0             NaN
# 3              True        NaN        NaN      NaN       NaN             NaN
# 4             False       83.0       48.0    189.0     156.0            52.0
#
#    longitude   latitude  elevation
# 0  40.728926  34.749855        223
# 1   4.631111  43.677778         21
# 2   4.830556  45.770556        206
# 3  12.494913  41.889950         22
# 4  12.492269  41.890169         22
#
# [5 rows x 24 columns]

# %%
df.tail()
# Out:
#                                  id  \
# 270  saintGeorgesDuBoisAmphitheater
# 271              toledoAmphitheater
# 272        kaiseraugustAmphitheater
# 273              ammaiaAmphitheater
# 274          contributaAmphitheater
#
#                                           title                  label  \
# 270       Amphitheater at Saint-Georges-du-Bois  Saint-Georges-du-Bois
# 271                      Amphitheater at Toledo                 Toledo
# 272                 Amphitheater at Kaiseraugst            Kaiseraugst
# 273                      Amphitheater at Ammaia                 Ammaia
# 274  Amphitheater at Contributa Iulia Ugultunia             Contributa
#
#                    latintoponym                                   pleiades  \
# 270                         NaN                                        NaN
# 271                     Toletum    https://pleiades.stoa.org/places/266066
# 272          Castrum Rauracense  https://pleiades.stoa.org/places/81716458
# 273                      Ammaia    https://pleiades.stoa.org/places/255975
# 274  Contributa Iulia Ugultunia    https://pleiades.stoa.org/places/256126
#
#      welchid  golvinid  buildingtype     chronogroup  secondcentury  ...  \
# 270      NaN     103.0  amphitheater   first-century           True  ...
# 271      NaN       NaN  amphitheater        imperial           True  ...
# 272      NaN       NaN  amphitheater  fourth-century          False  ...
# 273      NaN       NaN  amphitheater        imperial           True  ...
# 274      NaN       NaN  amphitheater        imperial           True  ...
#
#                            amphitheatrum dimensionsunknown arenamajor  \
# 270  https://amphi-theatrum.de/1529.html             False       54.0
# 271  https://amphi-theatrum.de/3090.html              True        NaN
# 272  https://amphi-theatrum.de/3066.html             False        NaN
# 273  https://amphi-theatrum.de/3020.html             False        NaN
# 274  https://amphi-theatrum.de/3093.html             False        NaN
#
#     arenaminor extmajor  extminor  exteriorheight  longitude   latitude  \
# 270       30.0     65.0      50.0             NaN  -0.749919  46.142723
# 271        NaN      NaN       NaN             NaN  -4.022888  39.865349
# 272        NaN     50.0      40.0             NaN   7.721596  47.540822
# 273        NaN     60.0       NaN             NaN  -7.391970  39.369905
# 274        NaN     72.0       NaN             NaN  -6.389320  38.347751
#
#      elevation
# 270         39
# 271        482
# 272        482
# 273        566
# 274        501
#
# [5 rows x 24 columns]

# %% [markdown]
# #### Data types in our csv

# %%
df.shape # notice that this is an attribute so no parentheses
# Out:
# (275, 24)

# %%
df.info() # notice that this is a methon, so we need parentheses
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 275 entries, 0 to 274
# Data columns (total 24 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 275 non-null    object
#  1   title              275 non-null    object
#  2   label              275 non-null    object
#  3   latintoponym       261 non-null    object
#  4   pleiades           274 non-null    object
#  5   welchid            19 non-null     float64
#  6   golvinid           166 non-null    float64
#  7   buildingtype       275 non-null    object
#  8   chronogroup        275 non-null    object
#  9   secondcentury      275 non-null    bool
#  10  capacity           153 non-null    float64
#  11  modcountry         275 non-null    object
#  12  romanregion        274 non-null    object
#  13  zotero             56 non-null     object
#  14  amphitheatrum      239 non-null    object
#  15  dimensionsunknown  275 non-null    bool
#  16  arenamajor         184 non-null    float64
#  17  arenaminor         179 non-null    float64
#  18  extmajor           219 non-null    float64
#  19  extminor           198 non-null    float64
#  20  exteriorheight     3 non-null      float64
#  21  longitude          275 non-null    float64
#  22  latitude           275 non-null    float64
#  23  elevation          275 non-null    int64
# dtypes: bool(2), float64(10), int64(1), object(11)
# memory usage: 47.9+ KB
